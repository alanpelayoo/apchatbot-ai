# %%
 
import json

from nltk.stem.lancaster import LancasterStemmer
from keras.models import Sequential 

#Importar capas
from keras.layers import Dense

#Importar regla de optimizacion
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD


stemmer = LancasterStemmer()

from data import DataProcessing #Import our class for data proccesing
from chat import chat

# %%
with open('intents.json') as file:
    data = json.load(file)
with open('intents2.json') as file:
    data2 = json.load(file)
    
chatbot_data = DataProcessing(data) #Constructor
chatbot_data.start_process() # Generate data

chatbot_test = DataProcessing(data2) #Constructor
chatbot_test.start_process() # Generate data
# Out:
# [] []
# [] []

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(chatbot_data.training[0]),), activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(len(chatbot_data.output[0]), activation='softmax'))

# %%
opt = Adam(learning_rate=0.05)
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

model.fit(chatbot_data.training, chatbot_data.output,epochs=1000, batch_size=5, verbose=1)
# Out:
# Epoch 1/1000
# c:\users\alahp\appdata\local\programs\python\python39\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5828 - accuracy: 0.3243
# Epoch 2/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5131 - accuracy: 0.5405
# Epoch 3/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4344 - accuracy: 0.5405
# Epoch 4/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3624 - accuracy: 0.4865
# Epoch 5/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2670 - accuracy: 0.6216
# Epoch 6/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1791 - accuracy: 0.7568
# Epoch 7/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0740 - accuracy: 0.8649
# Epoch 8/1000
# ...

# %%
print("test data")
print(data2)

# %%
valores = chat(chatbot_data,model,data)
# Out:
# Chatbot
# You: Hello good morning
# Hello
# [('greeting', '0.9999819')]
# Is labelcorrect?yes
# You: Are you located in Mexico?
# Hello we are located in Guadalajara Mexico
# [('location', '0.9989944')]
# Is labelcorrect?yes
# You: Id love to buy an insurance
# We sell different kind of insurances that would fit your wage, we will send you more info in a moment.
# [('shop', '0.99999964')]
# Is labelcorrect?yes
# You: When can I visit your office?
# We are open 7am-4pm Monday-Friday!
# [('hours', '0.8463661')]
# Is labelcorrect?no
# 0: greeting
# 1: goodbye
# 2: location
# 3: shop
# 4: hours
# Choose the correct label (int)4
# done
# You: quit

# %%
import matplotlib.pyplot as plt
plt.title("Error Modelo")
plt.xlabel("Prueba")
plt.ylabel("Error")
plt.grid()
plt.plot(index,valores, '*', color='red');
